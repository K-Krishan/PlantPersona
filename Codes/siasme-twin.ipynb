# %%
# The dataset should be in the format of

# -data
# --0
# --- 1st plant with ID 0
# --- 2nd plant with ID 0
#        ...
# ---
# --1
# ---1st plant with ID 1
# ---2nd plant with ID 1
#        ...
# ....
# --n
# --- 1st plant with ID n
# --- 2nd plant with ID n
#        ...

# %%
import random
import numpy as np
import keras
from keras import ops
import matplotlib.pyplot as plt
import os
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
epochs = 10
batch_size = 16
margin = 1  # Margin for contrastive loss.
def load_dataset(data_directory, img_size=(224, 224)):
    x, y = [], []
    for class_id in sorted(os.listdir(data_directory)):
        class_dir = os.path.join(data_directory, class_id)
        if not os.path.isdir(class_dir):
            continue
        for img_name in os.listdir(class_dir):
            img_path = os.path.join(class_dir, img_name)
            img = load_img(img_path, target_size=img_size) # or 'rgb' if your images are colored
            img = img_to_array(img)
            x.append(img)
            y.append(class_id)
    return np.array(x), np.array(y).astype("int64")

# Adapt these paths to where your dataset is located
train_val_directory = './data'
x_train_val, y_train_val = load_dataset(train_val_directory)

# Normalize the image data
x_train_val /= 255.0

# Split the loaded data into training and validation sets
x_train, x_test, y_train, y_test = train_test_split(x_train_val, y_train_val, test_size=0.8, random_state=42)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.7, random_state=42)
# Optionally, delete the original variables to free up memory
del x_train_val, y_train_val

def make_pairs(x, y):
    """Creates a tuple containing image pairs with corresponding label.

    Arguments:
        x: List containing images, each index in this list corresponds to one image.
        y: List containing labels, each label with datatype of `int`.

    Returns:
        Tuple containing two numpy arrays as (pairs_of_samples, labels),
        where pairs_of_samples' shape is (2len(x), 2,n_features_dims) and
        labels are a binary array of shape (2len(x)).
    """

    num_classes = max(y) + 1
    digit_indices = [np.where(y == i)[0] for i in range(num_classes)]

    pairs = []
    labels = []

    for idx1 in range(len(x)):
        # add a matching example
        x1 = x[idx1]
        label1 = y[idx1]
        idx2 = random.choice(digit_indices[label1])
        x2 = x[idx2]

        pairs += [[x1, x2]]
        labels += [0]

        # add a non-matching example
        label2 = random.randint(0, num_classes - 1)
        while label2 == label1:
            label2 = random.randint(0, num_classes - 1)

        idx2 = random.choice(digit_indices[label2])
        x2 = x[idx2]

        pairs += [[x1, x2]]
        labels += [1]

    return np.array(pairs), np.array(labels).astype("float32")


# make train pairs
pairs_train, labels_train = make_pairs(x_train, y_train)

# make validation pairs
pairs_val, labels_val = make_pairs(x_val, y_val)

# make test pairs
pairs_test, labels_test = make_pairs(x_test, y_test)
x_train_1 = pairs_train[:, 0]  # x_train_1.shape is (60000, 28, 28)
x_train_2 = pairs_train[:, 1]
x_val_1 = pairs_val[:, 0]  # x_val_1.shape = (60000, 28, 28)
x_val_2 = pairs_val[:, 1]
x_test_1 = pairs_test[:, 0]  # x_test_1.shape = (20000, 28, 28)
x_test_2 = pairs_test[:, 1]

# %%
epochs = 10
batch_size = 16
margin = 1  # Margin for contrastive loss.

# %%
# (x_train_val, y_train_val), (x_test, y_test) = keras.datasets.mnist.load_data()

# # Change the data type to a floating point format
# x_train_val = x_train_val.astype("float32")
# x_test = x_test.astype("float32")

# %%
# # Keep 50% of train_val  in validation set
# x_train, x_val = x_train_val[:30000], x_train_val[30000:]
# y_train, y_val = y_train_val[:30000], y_train_val[30000:]
# del x_train_val, y_train_val

# %%
def load_dataset(data_directory, img_size=(224, 224)):
    x, y = [], []
    for class_id in sorted(os.listdir(data_directory)):
        class_dir = os.path.join(data_directory, class_id)
        if not os.path.isdir(class_dir):
            continue
        for img_name in os.listdir(class_dir):
            img_path = os.path.join(class_dir, img_name)
            img = load_img(img_path, target_size=img_size) # or 'rgb' if your images are colored
            img = img_to_array(img)
            x.append(img)
            y.append(class_id)
    return np.array(x), np.array(y).astype("int64")

# Adapt these paths to where your dataset is located
train_val_directory = './data'
x_train_val, y_train_val = load_dataset(train_val_directory)

# Normalize the image data
x_train_val /= 255.0

# %%
# Split the loaded data into training and validation sets
x_train, x_test, y_train, y_test = train_test_split(x_train_val, y_train_val, test_size=0.8, random_state=42)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.7, random_state=42)
# Optionally, delete the original variables to free up memory
del x_train_val, y_train_val

# %%
def make_pairs(x, y):
    """Creates a tuple containing image pairs with corresponding label.

    Arguments:
        x: List containing images, each index in this list corresponds to one image.
        y: List containing labels, each label with datatype of `int`.

    Returns:
        Tuple containing two numpy arrays as (pairs_of_samples, labels),
        where pairs_of_samples' shape is (2len(x), 2,n_features_dims) and
        labels are a binary array of shape (2len(x)).
    """

    num_classes = max(y) + 1
    digit_indices = [np.where(y == i)[0] for i in range(num_classes)]

    pairs = []
    labels = []

    for idx1 in range(len(x)):
        # add a matching example
        x1 = x[idx1]
        label1 = y[idx1]
        idx2 = random.choice(digit_indices[label1])
        x2 = x[idx2]

        pairs += [[x1, x2]]
        labels += [0]

        # add a non-matching example
        label2 = random.randint(0, num_classes - 1)
        while label2 == label1:
            label2 = random.randint(0, num_classes - 1)

        idx2 = random.choice(digit_indices[label2])
        x2 = x[idx2]

        pairs += [[x1, x2]]
        labels += [1]

    return np.array(pairs), np.array(labels).astype("float32")


# make train pairs
pairs_train, labels_train = make_pairs(x_train, y_train)

# make validation pairs
pairs_val, labels_val = make_pairs(x_val, y_val)

# make test pairs
pairs_test, labels_test = make_pairs(x_test, y_test)

# %%
x_train_1 = pairs_train[:, 0]  # x_train_1.shape is (60000, 28, 28)
x_train_2 = pairs_train[:, 1]

# %%
x_val_1 = pairs_val[:, 0]  # x_val_1.shape = (60000, 28, 28)
x_val_2 = pairs_val[:, 1]

# %%
x_test_1 = pairs_test[:, 0]  # x_test_1.shape = (20000, 28, 28)
x_test_2 = pairs_test[:, 1]

# %%
def visualize(pairs, labels, to_show=6, num_col=3, predictions=None, test=False):
    """Creates a plot of pairs and labels, and prediction if it's test dataset.

    Arguments:
        pairs: Numpy Array, of pairs to visualize, having shape
               (Number of pairs, 2, 28, 28).
        to_show: Int, number of examples to visualize (default is 6)
                `to_show` must be an integral multiple of `num_col`.
                 Otherwise it will be trimmed if it is greater than num_col,
                 and incremented if if it is less then num_col.
        num_col: Int, number of images in one row - (default is 3)
                 For test and train respectively, it should not exceed 3 and 7.
        predictions: Numpy Array of predictions with shape (to_show, 1) -
                     (default is None)
                     Must be passed when test=True.
        test: Boolean telling whether the dataset being visualized is
              train dataset or test dataset - (default False).

    Returns:
        None.
    """

    # Define num_row
    # If to_show % num_col != 0
    #    trim to_show,
    #       to trim to_show limit num_row to the point where
    #       to_show % num_col == 0
    #
    # If to_show//num_col == 0
    #    then it means num_col is greater then to_show
    #    increment to_show
    #       to increment to_show set num_row to 1
    num_row = to_show // num_col if to_show // num_col != 0 else 1

    # `to_show` must be an integral multiple of `num_col`
    #  we found num_row and we have num_col
    #  to increment or decrement to_show
    #  to make it integral multiple of `num_col`
    #  simply set it equal to num_row * num_col
    to_show = num_row * num_col

    # Plot the images
    fig, axes = plt.subplots(num_row, num_col, figsize=(5, 5))
    for i in range(to_show):
        # If the number of rows is 1, the axes array is one-dimensional
        if num_row == 1:
            ax = axes[i % num_col]
        else:
            ax = axes[i // num_col, i % num_col]

        ax.imshow(ops.concatenate([pairs[i][0], pairs[i][1]], axis=1), cmap="gray")
        ax.set_axis_off()
        if test:
            ax.set_title("True: {} | Pred: {:.5f}".format(labels[i], predictions[i][0]))
        else:
            ax.set_title("Label: {}".format(labels[i]))
    if test:
        plt.tight_layout(rect=(0, 0, 1.9, 1.9), w_pad=0.0)
    else:
        plt.tight_layout(rect=(0, 0, 1.5, 1.5))
    plt.show()
visualize(pairs_train[:-1], labels_train[:-1], to_show=4, num_col=4)
visualize(pairs_val[:-1], labels_val[:-1], to_show=4, num_col=4)

visualize(pairs_test[:-1], labels_test[:-1], to_show=4, num_col=4)
# Provided two tensors t1 and t2
# Euclidean distance = sqrt(sum(square(t1-t2)))
def euclidean_distance(vects):
    """Find the Euclidean distance between two vectors.

    Arguments:
        vects: List containing two tensors of same length.

    Returns:
        Tensor containing euclidean distance
        (as floating point value) between vectors.
    """

    x, y = vects
    sum_square = ops.sum(ops.square(x - y), axis=1, keepdims=True)
    return ops.sqrt(ops.maximum(sum_square, keras.backend.epsilon()))


input = keras.layers.Input((224, 224, 3))
x = keras.layers.BatchNormalization()(input)
x = keras.layers.Conv2D(4, (5, 5), activation="tanh")(x)
x = keras.layers.AveragePooling2D(pool_size=(2, 2))(x)
x = keras.layers.Conv2D(16, (5, 5), activation="tanh")(x)
x = keras.layers.AveragePooling2D(pool_size=(2, 2))(x)
x = keras.layers.Flatten()(x)

x = keras.layers.BatchNormalization()(x)
x = keras.layers.Dense(10, activation="tanh")(x)
embedding_network = keras.Model(input, x)


input_1 = keras.layers.Input((224, 224, 3))
input_2 = keras.layers.Input((224, 224, 3))

# As mentioned above, Siamese Network share weights between
# tower networks (sister networks). To allow this, we will use
# same embedding network for both tower networks.
tower_1 = embedding_network(input_1)
tower_2 = embedding_network(input_2)

merge_layer = keras.layers.Lambda(euclidean_distance, output_shape=(1,))(
    [tower_1, tower_2]
)
normal_layer = keras.layers.BatchNormalization()(merge_layer)
output_layer = keras.layers.Dense(1, activation="sigmoid")(normal_layer)
siamese = keras.Model(inputs=[input_1, input_2], outputs=output_layer)
def loss(margin=1):
    """Provides 'contrastive_loss' an enclosing scope with variable 'margin'.

    Arguments:
        margin: Integer, defines the baseline for distance for which pairs
                should be classified as dissimilar. - (default is 1).

    Returns:
        'contrastive_loss' function with data ('margin') attached.
    """

    # Contrastive loss = mean( (1-true_value) * square(prediction) +
    #                         true_value * square( max(margin-prediction, 0) ))
    def contrastive_loss(y_true, y_pred):
        """Calculates the contrastive loss.

        Arguments:
            y_true: List of labels, each label is of type float32.
            y_pred: List of predictions of same length as of y_true,
                    each label is of type float32.

        Returns:
            A tensor containing contrastive loss as floating point value.
        """

        square_pred = ops.square(y_pred)
        margin_square = ops.square(ops.maximum(margin - (y_pred), 0))
        return ops.mean((1 - y_true) * square_pred + (y_true) * margin_square)

    return contrastive_loss
siamese.compile(loss=loss(margin=margin), optimizer="RMSprop", metrics=["accuracy"])
siamese.summary()
history = siamese.fit(
    [x_train_1, x_train_2],
    labels_train,
    validation_data=([x_val_1, x_val_2], labels_val),
    batch_size=batch_size,
    epochs=60,
)
def plt_metric(history, metric, title, has_valid=True):
    """Plots the given 'metric' from 'history'.

    Arguments:
        history: history attribute of History object returned from Model.fit.
        metric: Metric to plot, a string value present as key in 'history'.
        title: A string to be used as title of plot.
        has_valid: Boolean, true if valid data was passed to Model.fit else false.

    Returns:
        None.
    """
    plt.plot(history[metric])
    if has_valid:
        plt.plot(history["val_" + metric])
        plt.legend(["train", "validation"], loc="upper left")
    plt.title(title)
    plt.ylabel(metric)
    plt.xlabel("epoch")
    plt.show()


# Plot the accuracy
plt_metric(history=history.history, metric="accuracy", title="Model accuracy")

# Plot the contrastive loss
plt_metric(history=history.history, metric="loss", title="Contrastive Loss")
results = siamese.evaluate([x_test_1, x_test_2], labels_test)
print("test loss, test acc:", results)
predictions = siamese.predict([x_test_1, x_test_2])
visualize(pairs_test, labels_test, to_show=3, predictions=predictions, test=True)
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)    │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_layer_2 (InputLayer)    │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ functional_1 (Functional)     │ (None, 10)                │         631,158 │ input_layer_1[0][0],       │
# │                               │                           │                 │ input_layer_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lambda (Lambda)               │ (None, 1)                 │               0 │ functional_1[0][0],        │
# │                               │                           │                 │ functional_1[1][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 1)                 │               4 │ lambda[0][0]               │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 1)                 │               2 │ batch_normalization_2[0][… │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 631,164 (2.41 MB)
#  Trainable params: 541,268 (2.06 MB)
#  Non-trainable params: 89,896 (351.16 KB)
# Epoch 1/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 419ms/step - accuracy: 0.6464 - loss: 0.2142 - val_accuracy: 0.5741 - val_loss: 0.3045
# Epoch 2/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 268ms/step - accuracy: 0.6994 - loss: 0.2272 - val_accuracy: 0.5741 - val_loss: 0.3061
# Epoch 3/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 350ms/step - accuracy: 0.6946 - loss: 0.1790 - val_accuracy: 0.5648 - val_loss: 0.2968
# Epoch 4/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 335ms/step - accuracy: 0.6868 - loss: 0.2024 - val_accuracy: 0.5463 - val_loss: 0.2728
# Epoch 5/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 320ms/step - accuracy: 0.7694 - loss: 0.1592 - val_accuracy: 0.5463 - val_loss: 0.2818
# Epoch 6/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 320ms/step - accuracy: 0.7897 - loss: 0.1577 - val_accuracy: 0.5278 - val_loss: 0.2898
# Epoch 7/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 395ms/step - accuracy: 0.7819 - loss: 0.1303 - val_accuracy: 0.5741 - val_loss: 0.2897
# Epoch 8/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 291ms/step - accuracy: 0.7585 - loss: 0.1735 - val_accuracy: 0.5000 - val_loss: 0.2926
# Epoch 9/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 323ms/step - accuracy: 0.6712 - loss: 0.1540 - val_accuracy: 0.4907 - val_loss: 0.2848
# Epoch 10/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 277ms/step - accuracy: 0.7802 - loss: 0.1527 - val_accuracy: 0.5556 - val_loss: 0.3237
# Epoch 11/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 276ms/step - accuracy: 0.7476 - loss: 0.1729 - val_accuracy: 0.5648 - val_loss: 0.3030
# Epoch 12/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 307ms/step - accuracy: 0.8224 - loss: 0.1402 - val_accuracy: 0.5833 - val_loss: 0.2852
# Epoch 13/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - accuracy: 0.8910 - loss: 0.1298 - val_accuracy: 0.5000 - val_loss: 0.2983
# Epoch 14/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 275ms/step - accuracy: 0.8832 - loss: 0.1356 - val_accuracy: 0.5278 - val_loss: 0.2741
# Epoch 15/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - accuracy: 0.7415 - loss: 0.1649 - val_accuracy: 0.5185 - val_loss: 0.3059
# Epoch 16/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - accuracy: 0.8427 - loss: 0.1268 - val_accuracy: 0.5278 - val_loss: 0.2920
# Epoch 17/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step - accuracy: 0.8614 - loss: 0.1224 - val_accuracy: 0.5000 - val_loss: 0.3010
# Epoch 18/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step - accuracy: 0.9035 - loss: 0.1191 - val_accuracy: 0.5556 - val_loss: 0.2932
# Epoch 19/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step - accuracy: 0.9096 - loss: 0.1034 - val_accuracy: 0.5741 - val_loss: 0.3091
# Epoch 20/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 248ms/step - accuracy: 0.8458 - loss: 0.1065 - val_accuracy: 0.5463 - val_loss: 0.3051
# Epoch 21/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - accuracy: 0.9096 - loss: 0.1197 - val_accuracy: 0.5648 - val_loss: 0.3222
# Epoch 22/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 246ms/step - accuracy: 0.9548 - loss: 0.0891 - val_accuracy: 0.5463 - val_loss: 0.3133
# Epoch 23/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - accuracy: 0.8801 - loss: 0.1518 - val_accuracy: 0.5556 - val_loss: 0.3079
# Epoch 24/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step - accuracy: 0.7632 - loss: 0.1534 - val_accuracy: 0.5000 - val_loss: 0.3083
# Epoch 25/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 320ms/step - accuracy: 0.8037 - loss: 0.1202 - val_accuracy: 0.5648 - val_loss: 0.3145
# Epoch 26/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step - accuracy: 0.8584 - loss: 0.1121 - val_accuracy: 0.6111 - val_loss: 0.3184
# Epoch 27/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - accuracy: 0.8753 - loss: 0.1111 - val_accuracy: 0.5926 - val_loss: 0.3139
# Epoch 28/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step - accuracy: 0.8628 - loss: 0.1285 - val_accuracy: 0.5556 - val_loss: 0.3214
# Epoch 29/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 0.8614 - loss: 0.1208 - val_accuracy: 0.5463 - val_loss: 0.3215
# Epoch 30/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.8458 - loss: 0.1222 - val_accuracy: 0.5463 - val_loss: 0.3313
# Epoch 31/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - accuracy: 0.8505 - loss: 0.1301 - val_accuracy: 0.5556 - val_loss: 0.3091
# Epoch 32/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 358ms/step - accuracy: 0.7724 - loss: 0.1497 - val_accuracy: 0.5463 - val_loss: 0.2904
# Epoch 33/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 375ms/step - accuracy: 0.8692 - loss: 0.1135 - val_accuracy: 0.4907 - val_loss: 0.3061
# Epoch 34/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 387ms/step - accuracy: 0.8458 - loss: 0.1254 - val_accuracy: 0.4815 - val_loss: 0.2812
# Epoch 35/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 350ms/step - accuracy: 0.9283 - loss: 0.0873 - val_accuracy: 0.5185 - val_loss: 0.3105
# Epoch 36/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 382ms/step - accuracy: 0.8519 - loss: 0.1268 - val_accuracy: 0.5833 - val_loss: 0.3170
# Epoch 37/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - accuracy: 0.8536 - loss: 0.1075 - val_accuracy: 0.5833 - val_loss: 0.3060
# Epoch 38/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - accuracy: 0.8614 - loss: 0.1085 - val_accuracy: 0.5741 - val_loss: 0.3157
# Epoch 39/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 382ms/step - accuracy: 0.8240 - loss: 0.1148 - val_accuracy: 0.5463 - val_loss: 0.3242
# Epoch 40/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step - accuracy: 0.8879 - loss: 0.1023 - val_accuracy: 0.5278 - val_loss: 0.3252
# Epoch 41/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step - accuracy: 0.8645 - loss: 0.1032 - val_accuracy: 0.5648 - val_loss: 0.3287
# Epoch 42/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - accuracy: 0.9222 - loss: 0.1074 - val_accuracy: 0.5556 - val_loss: 0.3209
# Epoch 43/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 411ms/step - accuracy: 0.9704 - loss: 0.0972 - val_accuracy: 0.5556 - val_loss: 0.3254
# Epoch 44/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 400ms/step - accuracy: 0.8770 - loss: 0.1108 - val_accuracy: 0.5741 - val_loss: 0.3196
# Epoch 45/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 431ms/step - accuracy: 0.8784 - loss: 0.1105 - val_accuracy: 0.5648 - val_loss: 0.3233
# Epoch 46/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step - accuracy: 0.8723 - loss: 0.1157 - val_accuracy: 0.5833 - val_loss: 0.3332
# Epoch 47/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step - accuracy: 0.8302 - loss: 0.1266 - val_accuracy: 0.5741 - val_loss: 0.3310
# Epoch 48/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - accuracy: 0.7632 - loss: 0.1335 - val_accuracy: 0.5833 - val_loss: 0.3212
# Epoch 49/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step - accuracy: 0.8801 - loss: 0.1057 - val_accuracy: 0.5556 - val_loss: 0.3236
# Epoch 50/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 269ms/step - accuracy: 0.7850 - loss: 0.1345 - val_accuracy: 0.5278 - val_loss: 0.3276
# Epoch 51/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 285ms/step - accuracy: 0.8723 - loss: 0.1142 - val_accuracy: 0.5463 - val_loss: 0.2803
# Epoch 52/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 303ms/step - accuracy: 0.8614 - loss: 0.1129 - val_accuracy: 0.5370 - val_loss: 0.2877
# Epoch 53/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 388ms/step - accuracy: 0.8645 - loss: 0.0948 - val_accuracy: 0.5000 - val_loss: 0.2956
# Epoch 54/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 312ms/step - accuracy: 0.8801 - loss: 0.1022 - val_accuracy: 0.5741 - val_loss: 0.2831
# Epoch 55/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 259ms/step - accuracy: 0.9657 - loss: 0.0815 - val_accuracy: 0.5741 - val_loss: 0.2810
# Epoch 56/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 284ms/step - accuracy: 0.9144 - loss: 0.1030 - val_accuracy: 0.5648 - val_loss: 0.2917
# Epoch 57/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 257ms/step - accuracy: 0.8567 - loss: 0.0970 - val_accuracy: 0.5463 - val_loss: 0.2941
# Epoch 58/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - accuracy: 0.9175 - loss: 0.0864 - val_accuracy: 0.5648 - val_loss: 0.2999
# Epoch 59/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 306ms/step - accuracy: 0.9674 - loss: 0.0723 - val_accuracy: 0.5833 - val_loss: 0.2842
# Epoch 60/60
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - accuracy: 0.8723 - loss: 0.0939 - val_accuracy: 0.5556 - val_loss: 0.3036
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.5938 - loss: 0.2738
# test loss, test acc: [0.2833438813686371, 0.590032160282135]
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step

# %%
visualize(pairs_train[:-1], labels_train[:-1], to_show=4, num_col=4)

# %%
visualize(pairs_val[:-1], labels_val[:-1], to_show=4, num_col=4)

# %%
visualize(pairs_test[:-1], labels_test[:-1], to_show=4, num_col=4)

# %%
# Provided two tensors t1 and t2
# Euclidean distance = sqrt(sum(square(t1-t2)))
def euclidean_distance(vects):
    """Find the Euclidean distance between two vectors.

    Arguments:
        vects: List containing two tensors of same length.

    Returns:
        Tensor containing euclidean distance
        (as floating point value) between vectors.
    """

    x, y = vects
    sum_square = ops.sum(ops.square(x - y), axis=1, keepdims=True)
    return ops.sqrt(ops.maximum(sum_square, keras.backend.epsilon()))


input = keras.layers.Input((224, 224, 3))
x = keras.layers.BatchNormalization()(input)
x = keras.layers.Conv2D(4, (5, 5), activation="tanh")(x)
x = keras.layers.AveragePooling2D(pool_size=(2, 2))(x)
x = keras.layers.Conv2D(16, (5, 5), activation="tanh")(x)
x = keras.layers.AveragePooling2D(pool_size=(2, 2))(x)
x = keras.layers.Flatten()(x)

x = keras.layers.BatchNormalization()(x)
x = keras.layers.Dense(10, activation="tanh")(x)
embedding_network = keras.Model(input, x)


input_1 = keras.layers.Input((224, 224, 3))
input_2 = keras.layers.Input((224, 224, 3))

# As mentioned above, Siamese Network share weights between
# tower networks (sister networks). To allow this, we will use
# same embedding network for both tower networks.
tower_1 = embedding_network(input_1)
tower_2 = embedding_network(input_2)

merge_layer = keras.layers.Lambda(euclidean_distance, output_shape=(1,))(
    [tower_1, tower_2]
)
normal_layer = keras.layers.BatchNormalization()(merge_layer)
output_layer = keras.layers.Dense(1, activation="sigmoid")(normal_layer)
siamese = keras.Model(inputs=[input_1, input_2], outputs=output_layer)

# %%
def loss(margin=1):
    """Provides 'contrastive_loss' an enclosing scope with variable 'margin'.

    Arguments:
        margin: Integer, defines the baseline for distance for which pairs
                should be classified as dissimilar. - (default is 1).

    Returns:
        'contrastive_loss' function with data ('margin') attached.
    """

    # Contrastive loss = mean( (1-true_value) * square(prediction) +
    #                         true_value * square( max(margin-prediction, 0) ))
    def contrastive_loss(y_true, y_pred):
        """Calculates the contrastive loss.

        Arguments:
            y_true: List of labels, each label is of type float32.
            y_pred: List of predictions of same length as of y_true,
                    each label is of type float32.

        Returns:
            A tensor containing contrastive loss as floating point value.
        """

        square_pred = ops.square(y_pred)
        margin_square = ops.square(ops.maximum(margin - (y_pred), 0))
        return ops.mean((1 - y_true) * square_pred + (y_true) * margin_square)

    return contrastive_loss

# %%
siamese.compile(loss=loss(margin=margin), optimizer="RMSprop", metrics=["accuracy"])
siamese.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)    │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_layer_5 (InputLayer)    │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ functional_5 (Functional)     │ (None, 10)                │         631,158 │ input_layer_4[0][0],       │
# │                               │                           │                 │ input_layer_5[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lambda_1 (Lambda)             │ (None, 1)                 │               0 │ functional_5[0][0],        │
# │                               │                           │                 │ functional_5[1][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_5         │ (None, 1)                 │               4 │ lambda_1[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 1)                 │               2 │ batch_normalization_5[0][… │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 631,164 (2.41 MB)
#  Trainable params: 541,268 (2.06 MB)
#  Non-trainable params: 89,896 (351.16 KB)

# %%
history = siamese.fit(
    [x_train_1, x_train_2],
    labels_train,
    validation_data=([x_val_1, x_val_2], labels_val),
    batch_size=batch_size,
    epochs=100,
)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 481ms/step - accuracy: 0.4062 - loss: 0.4450 - val_accuracy: 0.4444 - val_loss: 0.3162
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 304ms/step - accuracy: 0.3988 - loss: 0.3862 - val_accuracy: 0.4444 - val_loss: 0.3288
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 317ms/step - accuracy: 0.4192 - loss: 0.3791 - val_accuracy: 0.4167 - val_loss: 0.3764
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - accuracy: 0.3441 - loss: 0.4067 - val_accuracy: 0.3981 - val_loss: 0.3899
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step - accuracy: 0.3550 - loss: 0.4120 - val_accuracy: 0.4167 - val_loss: 0.3556
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.4969 - loss: 0.3737 - val_accuracy: 0.3519 - val_loss: 0.3836
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 331ms/step - accuracy: 0.5187 - loss: 0.3279 - val_accuracy: 0.4815 - val_loss: 0.3203
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 234ms/step - accuracy: 0.5000 - loss: 0.3557 - val_accuracy: 0.4444 - val_loss: 0.3232
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - accuracy: 0.4749 - loss: 0.3506 - val_accuracy: 0.4537 - val_loss: 0.3148
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - accuracy: 0.4626 - loss: 0.3680 - val_accuracy: 0.3889 - val_loss: 0.3424
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 265ms/step - accuracy: 0.3471 - loss: 0.4336 - val_accuracy: 0.4907 - val_loss: 0.2874
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 282ms/step - accuracy: 0.4144 - loss: 0.3769 - val_accuracy: 0.4815 - val_loss: 0.3159
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 274ms/step - accuracy: 0.6090 - loss: 0.3127 - val_accuracy: 0.4352 - val_loss: 0.3337
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.5109 - loss: 0.3603 - val_accuracy: 0.4167 - val_loss: 0.3927
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.5204 - loss: 0.3211 - val_accuracy: 0.4722 - val_loss: 0.3605
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 325ms/step - accuracy: 0.4501 - loss: 0.3366 - val_accuracy: 0.4444 - val_loss: 0.3519
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step - accuracy: 0.5374 - loss: 0.3268 - val_accuracy: 0.4537 - val_loss: 0.3671
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - accuracy: 0.4609 - loss: 0.3392 - val_accuracy: 0.4907 - val_loss: 0.3348
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - accuracy: 0.5686 - loss: 0.3066 - val_accuracy: 0.4630 - val_loss: 0.3412
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 235ms/step - accuracy: 0.5404 - loss: 0.3147 - val_accuracy: 0.4722 - val_loss: 0.3363
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - accuracy: 0.5357 - loss: 0.2963 - val_accuracy: 0.4444 - val_loss: 0.3658
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step - accuracy: 0.6029 - loss: 0.2533 - val_accuracy: 0.4074 - val_loss: 0.3964
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 234ms/step - accuracy: 0.4983 - loss: 0.3321 - val_accuracy: 0.4074 - val_loss: 0.3887
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 234ms/step - accuracy: 0.5686 - loss: 0.2656 - val_accuracy: 0.3981 - val_loss: 0.3917
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 235ms/step - accuracy: 0.3798 - loss: 0.3733 - val_accuracy: 0.4259 - val_loss: 0.3983
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.5781 - loss: 0.2922 - val_accuracy: 0.4352 - val_loss: 0.4025
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - accuracy: 0.5187 - loss: 0.3372 - val_accuracy: 0.4444 - val_loss: 0.3911
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 234ms/step - accuracy: 0.5686 - loss: 0.3004 - val_accuracy: 0.4352 - val_loss: 0.3982
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 237ms/step - accuracy: 0.5078 - loss: 0.3300 - val_accuracy: 0.4537 - val_loss: 0.3776
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 234ms/step - accuracy: 0.5734 - loss: 0.3324 - val_accuracy: 0.4907 - val_loss: 0.3617
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 254ms/step - accuracy: 0.4440 - loss: 0.3207 - val_accuracy: 0.4630 - val_loss: 0.3814
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step - accuracy: 0.4361 - loss: 0.3196 - val_accuracy: 0.4815 - val_loss: 0.3746
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 272ms/step - accuracy: 0.4531 - loss: 0.3208 - val_accuracy: 0.4722 - val_loss: 0.3754
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 0.3893 - loss: 0.3778 - val_accuracy: 0.3981 - val_loss: 0.3968
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 313ms/step - accuracy: 0.4688 - loss: 0.3315 - val_accuracy: 0.4259 - val_loss: 0.4151
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 307ms/step - accuracy: 0.5747 - loss: 0.3152 - val_accuracy: 0.4074 - val_loss: 0.3956
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 292ms/step - accuracy: 0.5234 - loss: 0.3407 - val_accuracy: 0.4074 - val_loss: 0.4042
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 368ms/step - accuracy: 0.3923 - loss: 0.3669 - val_accuracy: 0.4167 - val_loss: 0.4018
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 301ms/step - accuracy: 0.4922 - loss: 0.3518 - val_accuracy: 0.3889 - val_loss: 0.4032
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 317ms/step - accuracy: 0.5560 - loss: 0.3255 - val_accuracy: 0.3611 - val_loss: 0.4160
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - accuracy: 0.5078 - loss: 0.3139 - val_accuracy: 0.3796 - val_loss: 0.4425
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 268ms/step - accuracy: 0.5078 - loss: 0.3210 - val_accuracy: 0.3889 - val_loss: 0.4308
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step - accuracy: 0.5547 - loss: 0.3219 - val_accuracy: 0.4074 - val_loss: 0.4284
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 294ms/step - accuracy: 0.5421 - loss: 0.3071 - val_accuracy: 0.4259 - val_loss: 0.4120
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 382ms/step - accuracy: 0.4922 - loss: 0.3294 - val_accuracy: 0.4074 - val_loss: 0.4148
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 259ms/step - accuracy: 0.5639 - loss: 0.3104 - val_accuracy: 0.3981 - val_loss: 0.4055
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 316ms/step - accuracy: 0.6107 - loss: 0.2935 - val_accuracy: 0.3981 - val_loss: 0.3911
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 316ms/step - accuracy: 0.5717 - loss: 0.3146 - val_accuracy: 0.4167 - val_loss: 0.3921
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 380ms/step - accuracy: 0.5560 - loss: 0.3131 - val_accuracy: 0.4259 - val_loss: 0.3950
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 333ms/step - accuracy: 0.5435 - loss: 0.3171 - val_accuracy: 0.3981 - val_loss: 0.3936
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 359ms/step - accuracy: 0.5999 - loss: 0.2828 - val_accuracy: 0.4537 - val_loss: 0.3954
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - accuracy: 0.6247 - loss: 0.2802 - val_accuracy: 0.4537 - val_loss: 0.3916
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 371ms/step - accuracy: 0.4688 - loss: 0.3084 - val_accuracy: 0.4630 - val_loss: 0.3835
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 304ms/step - accuracy: 0.5764 - loss: 0.2940 - val_accuracy: 0.4352 - val_loss: 0.3823
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - accuracy: 0.5014 - loss: 0.3320 - val_accuracy: 0.4259 - val_loss: 0.3855
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 286ms/step - accuracy: 0.5326 - loss: 0.3197 - val_accuracy: 0.4630 - val_loss: 0.3775
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 280ms/step - accuracy: 0.5404 - loss: 0.2826 - val_accuracy: 0.4352 - val_loss: 0.3777
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 261ms/step - accuracy: 0.5156 - loss: 0.2855 - val_accuracy: 0.4630 - val_loss: 0.3781
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 306ms/step - accuracy: 0.5825 - loss: 0.3074 - val_accuracy: 0.4259 - val_loss: 0.3938
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 325ms/step - accuracy: 0.6029 - loss: 0.2931 - val_accuracy: 0.4444 - val_loss: 0.3837
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 321ms/step - accuracy: 0.5734 - loss: 0.3033 - val_accuracy: 0.4444 - val_loss: 0.3817
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step - accuracy: 0.5156 - loss: 0.2995 - val_accuracy: 0.4722 - val_loss: 0.3697
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 234ms/step - accuracy: 0.5465 - loss: 0.3214 - val_accuracy: 0.4722 - val_loss: 0.3706
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 398ms/step - accuracy: 0.5122 - loss: 0.3383 - val_accuracy: 0.4259 - val_loss: 0.3859
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 278ms/step - accuracy: 0.5795 - loss: 0.2852 - val_accuracy: 0.4167 - val_loss: 0.3879
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - accuracy: 0.4874 - loss: 0.3370 - val_accuracy: 0.3981 - val_loss: 0.3877
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.4983 - loss: 0.3328 - val_accuracy: 0.4630 - val_loss: 0.3713
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - accuracy: 0.4844 - loss: 0.3219 - val_accuracy: 0.4444 - val_loss: 0.3704
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 247ms/step - accuracy: 0.6107 - loss: 0.2955 - val_accuracy: 0.4630 - val_loss: 0.3688
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.5873 - loss: 0.3006 - val_accuracy: 0.4352 - val_loss: 0.3695
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.5639 - loss: 0.3042 - val_accuracy: 0.4352 - val_loss: 0.3614
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.5122 - loss: 0.3378 - val_accuracy: 0.4352 - val_loss: 0.3601
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 292ms/step - accuracy: 0.6776 - loss: 0.2793 - val_accuracy: 0.4259 - val_loss: 0.3619
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step - accuracy: 0.5812 - loss: 0.2903 - val_accuracy: 0.4537 - val_loss: 0.3604
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 344ms/step - accuracy: 0.4592 - loss: 0.3275 - val_accuracy: 0.4444 - val_loss: 0.3345
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step - accuracy: 0.6277 - loss: 0.2955 - val_accuracy: 0.4722 - val_loss: 0.3426
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 302ms/step - accuracy: 0.6681 - loss: 0.2813 - val_accuracy: 0.4537 - val_loss: 0.3309
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 285ms/step - accuracy: 0.6338 - loss: 0.2852 - val_accuracy: 0.4444 - val_loss: 0.3326
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 322ms/step - accuracy: 0.6247 - loss: 0.2918 - val_accuracy: 0.4352 - val_loss: 0.3365
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 279ms/step - accuracy: 0.6729 - loss: 0.2624 - val_accuracy: 0.4444 - val_loss: 0.3450
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 285ms/step - accuracy: 0.6838 - loss: 0.2692 - val_accuracy: 0.4074 - val_loss: 0.3483
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 338ms/step - accuracy: 0.6012 - loss: 0.2722 - val_accuracy: 0.4537 - val_loss: 0.3553
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 273ms/step - accuracy: 0.6464 - loss: 0.2615 - val_accuracy: 0.3981 - val_loss: 0.3605
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 273ms/step - accuracy: 0.6715 - loss: 0.2413 - val_accuracy: 0.4074 - val_loss: 0.3549
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 367ms/step - accuracy: 0.6760 - loss: 0.2872 - val_accuracy: 0.4444 - val_loss: 0.3474
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step - accuracy: 0.6746 - loss: 0.2684 - val_accuracy: 0.3889 - val_loss: 0.3516
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 341ms/step - accuracy: 0.6698 - loss: 0.2518 - val_accuracy: 0.3981 - val_loss: 0.3545
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 268ms/step - accuracy: 0.7120 - loss: 0.2499 - val_accuracy: 0.4630 - val_loss: 0.3516
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - accuracy: 0.6260 - loss: 0.2801 - val_accuracy: 0.4167 - val_loss: 0.3368
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 275ms/step - accuracy: 0.5340 - loss: 0.3215 - val_accuracy: 0.4167 - val_loss: 0.3536
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 275ms/step - accuracy: 0.6573 - loss: 0.2651 - val_accuracy: 0.4444 - val_loss: 0.3565
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 282ms/step - accuracy: 0.6355 - loss: 0.2717 - val_accuracy: 0.4167 - val_loss: 0.3628
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step - accuracy: 0.6620 - loss: 0.2729 - val_accuracy: 0.4259 - val_loss: 0.3643
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 259ms/step - accuracy: 0.6885 - loss: 0.2793 - val_accuracy: 0.4074 - val_loss: 0.3565
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - accuracy: 0.6090 - loss: 0.2696 - val_accuracy: 0.4167 - val_loss: 0.3506
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - accuracy: 0.6760 - loss: 0.2799 - val_accuracy: 0.4167 - val_loss: 0.3516
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - accuracy: 0.6012 - loss: 0.2690 - val_accuracy: 0.4074 - val_loss: 0.3542
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 0.7041 - loss: 0.2729 - val_accuracy: 0.4259 - val_loss: 0.3559
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - accuracy: 0.6464 - loss: 0.3026 - val_accuracy: 0.4074 - val_loss: 0.3570
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - accuracy: 0.6916 - loss: 0.2614 - val_accuracy: 0.4167 - val_loss: 0.3526

# %%
def plt_metric(history, metric, title, has_valid=True):
    """Plots the given 'metric' from 'history'.

    Arguments:
        history: history attribute of History object returned from Model.fit.
        metric: Metric to plot, a string value present as key in 'history'.
        title: A string to be used as title of plot.
        has_valid: Boolean, true if valid data was passed to Model.fit else false.

    Returns:
        None.
    """
    plt.plot(history[metric])
    if has_valid:
        plt.plot(history["val_" + metric])
        plt.legend(["train", "validation"], loc="upper left")
    plt.title(title)
    plt.ylabel(metric)
    plt.xlabel("epoch")
    plt.show()


# Plot the accuracy
plt_metric(history=history.history, metric="accuracy", title="Model accuracy")

# Plot the contrastive loss
plt_metric(history=history.history, metric="loss", title="Contrastive Loss")

# %%
results = siamese.evaluate([x_test_1, x_test_2], labels_test)
print("test loss, test acc:", results)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.4298 - loss: 0.3275
# test loss, test acc: [0.32298463582992554, 0.4421221911907196]

# %%
predictions = siamese.predict([x_test_1, x_test_2])
visualize(pairs_test, labels_test, to_show=3, predictions=predictions, test=True)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
