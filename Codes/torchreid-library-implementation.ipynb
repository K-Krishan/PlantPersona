# %%
# The dataset should be in the format of

# -data
# --0
# --- 1st plant with ID 0
# --- 2nd plant with ID 0
#        ...
# ---
# --1
# ---1st plant with ID 1
# ---2nd plant with ID 1
#        ...
# ....
# --n
# --- 1st plant with ID n
# --- 2nd plant with ID n
#        ...

# %%
import torchreid
import random
# Out:
# C:\Users\Krishna Kant\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchreid\reid\metrics\rank.py:11: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   warnings.warn(

# %%
torchreid.models.show_avai_models()
# Out:
# ['resnet18', 'resnet34', 'resnet50', 'resnet101', 'resnet152', 'resnext50_32x4d', 'resnext101_32x8d', 'resnet50_fc512', 'se_resnet50', 'se_resnet50_fc512', 'se_resnet101', 'se_resnext50_32x4d', 'se_resnext101_32x4d', 'densenet121', 'densenet169', 'densenet201', 'densenet161', 'densenet121_fc512', 'inceptionresnetv2', 'inceptionv4', 'xception', 'resnet50_ibn_a', 'resnet50_ibn_b', 'nasnsetmobile', 'mobilenetv2_x1_0', 'mobilenetv2_x1_4', 'shufflenet', 'squeezenet1_0', 'squeezenet1_0_fc512', 'squeezenet1_1', 'shufflenet_v2_x0_5', 'shufflenet_v2_x1_0', 'shufflenet_v2_x1_5', 'shufflenet_v2_x2_0', 'mudeep', 'resnet50mid', 'hacnn', 'pcb_p6', 'pcb_p4', 'mlfn', 'osnet_x1_0', 'osnet_x0_75', 'osnet_x0_5', 'osnet_x0_25', 'osnet_ibn_x1_0', 'osnet_ain_x1_0', 'osnet_ain_x0_75', 'osnet_ain_x0_5', 'osnet_ain_x0_25']

# %%
from __future__ import absolute_import
from __future__ import print_function
from __future__ import division

# %%
import sys
import os
import os.path as osp

from torchreid.reid.data import ImageDataset

# %%
# dataset_dir = 'data'
# root = osp.abspath(osp.expanduser(''))
# dataset_dir = osp.join(root, dataset_dir)

# %%
# dataset_dir

# %%
# data = list()
# for class_name in os.listdir(dataset_dir):
#     for image in os.listdir(osp.join(dataset_dir, class_name)):
#         data.append((image, int(class_name), 0)) # 0 is default camera since we only used one
# print(data)

# %%
class NewDataset(ImageDataset):
    dataset_dir = 'data'

    def __init__(self, root='', **kwargs):
        self.root = osp.abspath(osp.expanduser(root))
        self.dataset_dir = osp.join(self.root, self.dataset_dir)
        # preparing data splits
        train, query, gallery = list(), list(), list()
        for class_name in os.listdir(self.dataset_dir):
            for image in os.listdir(osp.join(self.dataset_dir, class_name)):
                gallery.append((osp.join(self.dataset_dir, class_name, image), int(class_name), 1))
                if random.random() < 0.8:
                    train.append((osp.join(self.dataset_dir, class_name, image), int(class_name), 0))
                else:
                    query.append((osp.join(self.dataset_dir, class_name, image), int(class_name), 0)) # 0 is default camera since we only used one

        super(NewDataset, self).__init__(train, query, gallery, **kwargs)

# %%
torchreid.data.register_image_dataset('palm_dataset', NewDataset)

# %%
# use your own dataset only
datamanager = torchreid.data.ImageDataManager(
    root='',
    sources='palm_dataset',
    targets='palm_dataset',
    workers=0,
)
# Out:
# Building train transforms ...
# + resize to 256x128
# + random flip
# + to torch tensor of range [0, 1]
# + normalization (mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# Building test transforms ...
# + resize to 256x128
# + to torch tensor of range [0, 1]
# + normalization (mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# => Loading train (source) dataset
# => Loaded NewDataset
#   ----------------------------------------
#   subset   | # ids | # images | # cameras
#   ----------------------------------------
#   train    |     8 |      313 |         1
#   query    |     8 |       75 |         1
#   gallery  |     8 |      388 |         1
#   ----------------------------------------
# => Loading test (target) dataset
# => Loaded NewDataset
#   ----------------------------------------
#   subset   | # ids | # images | # cameras
#   ----------------------------------------
#   train    |     8 |      325 |         1
#   query    |     8 |       63 |         1
#   gallery  |     8 |      388 |         1
#   ----------------------------------------
#
#
#   **************** Summary ****************
#   source            : ['palm_dataset']
#   # source datasets : 1
#   # source ids      : 8
#   # source images   : 313
#   # source cameras  : 1
#   target            : ['palm_dataset']
#   *****************************************

# %%
datamanager.train_loader.dataset.train
# Out:
# [('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\1_8_1.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\1_8_3.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\1_8_4.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\1_8_5.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\2_8_1.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\2_8_2.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\2_8_4.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\3_8_1.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\3_8_10.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\3_8_2.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\3_8_3.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\3_8_4.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\3_8_5.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\3_8_6.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\3_8_7.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\3_8_8.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\3_8_9.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\4_8_1.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\4_8_10.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\4_8_2.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\4_8_5.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\4_8_7.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\4_8_8.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\4_8_9.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\5_8_1.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\5_8_10.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\5_8_2.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\5_8_3.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\5_8_5.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\5_8_6.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\5_8_7.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\5_8_9.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\6_8_1.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\6_8_10.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\6_8_2.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\6_8_3.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\6_8_4.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\6_8_5.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\6_8_6.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\6_8_7.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\0\\6_8_9.jpg',
#   0,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\1_1_1.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\1_1_4.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\1_1_5.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\2_1_1.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\2_1_2.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\2_1_3.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\2_1_4.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\2_1_5.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\3_1_1.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\3_1_10.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\3_1_2.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\3_1_4.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\3_1_5.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\3_1_7.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\3_1_8.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\3_1_9.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\4_1_1.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\4_1_10.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\4_1_2.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\4_1_3.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\4_1_4.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\4_1_5.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\4_1_6.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\4_1_7.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\4_1_8.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\5_1_1.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\5_1_10.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\5_1_2.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\5_1_3.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\5_1_4.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\5_1_6.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\5_1_7.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\5_1_9.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\6_1_1.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\6_1_10.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\6_1_2.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\6_1_3.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\6_1_5.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\6_1_6.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\6_1_7.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\6_1_8.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\1\\6_1_9.jpg',
#   1,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\1_2_2.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\1_2_3.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\1_2_4.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\2_2_1.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\2_2_2.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\2_2_3.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\2_2_4.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\3_2_1.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\3_2_10.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\3_2_4.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\3_2_7.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\3_2_8.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\3_2_9.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\4_2_1.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\4_2_10.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\4_2_2.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\4_2_5.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\4_2_6.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\4_2_8.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\5_2_5.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\5_2_6.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\5_2_7.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\5_2_8.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\5_2_9.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\6_2_1.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\6_2_10.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\6_2_2.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\6_2_3.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\6_2_4.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\6_2_7.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\2\\6_2_9.jpg',
#   2,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\1_3_1.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\1_3_3.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\1_3_4.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\1_3_5.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\2_3_4.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\2_3_5.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\3_3_1.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\3_3_10.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\3_3_2.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\3_3_4.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\3_3_5.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\3_3_6.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\3_3_7.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\3_3_8.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\4_3_1.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\4_3_10.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\4_3_2.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\4_3_3.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\4_3_4.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\4_3_5.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\4_3_6.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\4_3_7.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\4_3_8.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\4_3_9.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\5_3_10.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\5_3_2.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\5_3_3.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\5_3_4.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\5_3_6.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\5_3_8.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\5_3_9.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\6_3_1.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\6_3_10.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\6_3_2.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\6_3_3.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\6_3_4.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\6_3_5.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\6_3_6.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\6_3_7.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\6_3_8.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\3\\6_3_9.jpg',
#   3,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\1_4_2.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\1_4_3.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\1_4_4.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\1_4_5.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\2_4_2.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\2_4_3.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\2_4_4.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\2_4_5.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\3_4_1.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\3_4_10.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\3_4_2.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\3_4_3.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\3_4_4.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\3_4_5.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\3_4_6.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\3_4_7.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\3_4_8.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\3_4_9.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\4_4_1.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\4_4_10.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\4_4_2.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\4_4_3.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\4_4_4.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\4_4_5.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\4_4_6.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\4_4_7.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\4_4_8.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\4_4_9.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\5_4_1.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\5_4_10.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\5_4_2.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\5_4_5.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\5_4_7.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\5_4_8.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\6_4_1.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\6_4_10.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\6_4_2.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\6_4_3.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\6_4_4.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\6_4_6.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\6_4_7.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\4\\6_4_9.jpg',
#   4,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\1_5_1.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\1_5_3.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\1_5_5.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\2_5_1.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\2_5_2.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\2_5_3.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\2_5_4.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\2_5_5.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\3_5_1.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\3_5_3.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\3_5_4.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\3_5_5.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\3_5_6.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\3_5_7.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\3_5_8.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\3_5_9.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\4_5_1.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\4_5_10.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\4_5_2.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\4_5_3.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\4_5_4.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\4_5_5.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\4_5_6.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\4_5_7.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\4_5_8.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\5_5_1.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\5_5_10.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\5_5_2.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\5_5_3.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\5_5_4.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\5_5_5.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\5_5_6.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\5_5_7.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\5_5_8.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\5_5_9.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\6_5_1.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\6_5_10.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\6_5_3.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\6_5_6.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\6_5_7.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\6_5_8.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\5\\6_5_9.jpg',
#   5,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\1_6_2.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\1_6_3.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\1_6_4.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\1_6_5.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\2_6_2.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\2_6_3.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\2_6_4.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\2_6_5.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\3_6_2.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\3_6_3.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\3_6_5.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\3_6_7.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\3_6_8.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\3_6_9.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\4_6_1.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\4_6_10.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\4_6_2.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\4_6_3.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\4_6_4.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\4_6_5.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\4_6_6.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\4_6_8.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\5_6_1.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\5_6_10.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\5_6_2.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\5_6_5.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\5_6_7.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\5_6_9.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\6_6_10.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\6_6_2.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\6_6_4.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\6_6_5.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\6\\6_6_8.jpg',
#   6,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\1_7_1.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\1_7_2.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\1_7_3.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\1_7_5.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\2_7_1.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\2_7_2.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\2_7_4.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\2_7_5.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\3_7_1.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\3_7_10.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\3_7_2.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\3_7_3.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\3_7_4.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\3_7_6.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\3_7_7.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\3_7_9.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\4_7_1.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\4_7_10.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\4_7_2.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\4_7_5.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\4_7_6.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\4_7_7.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\4_7_8.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\4_7_9.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\5_7_1.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\5_7_10.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\5_7_2.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\5_7_3.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\5_7_4.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\5_7_5.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\5_7_8.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\5_7_9.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\6_7_1.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\6_7_10.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\6_7_2.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\6_7_4.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\6_7_5.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\6_7_6.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\6_7_7.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\6_7_8.jpg',
#   7,
#   0,
#   0),
#  ('C:\\Users\\Krishna Kant\\Desktop\\acps project\\data\\7\\6_7_9.jpg',
#   7,
#   0,
#   0)]

# %%
from torchreid import models, utils

# %%
model = torchreid.models.build_model(
    name="resnet50",
    num_classes=datamanager.num_train_pids,
    loss="softmax",
    pretrained=True
)

# %%
model = model.cuda()

# %%
optimizer = torchreid.optim.build_optimizer(
    model,
    optim="adam",
    lr=0.0003
)

scheduler = torchreid.optim.build_lr_scheduler(
    optimizer,
    lr_scheduler="single_step",
    stepsize=20
)

# %%
engine = torchreid.engine.ImageSoftmaxEngine(
    datamanager,
    model,
    optimizer=optimizer,
    scheduler=scheduler,
    label_smooth=True
)

# %%
engine.run(
    save_dir='log/resnet50',
    max_epoch=60,
    eval_freq=10,
    print_freq=10,
    test_only=False,
    # fixbase_epoch=5,
    open_layers='classifier'
)
# Out:
# => Start training
# ##### Evaluating palm_dataset (source) #####
# Extracting features from query set ...
# Done, obtained 63-by-2048 matrix
# Extracting features from gallery set ...
# Done, obtained 388-by-2048 matrix
# Speed: 0.0243 sec/batch
# Computing distance matrix with metric=euclidean ...
# Computing CMC and mAP ...
# ** Results **
# mAP: 99.4%
# CMC curve
# Rank-1  : 100.0%
# Rank-5  : 100.0%
# Rank-10 : 100.0%
# Rank-20 : 100.0%
# Checkpoint saved to "log/resnet50\model\model.pth.tar-10"
# ##### Evaluating palm_dataset (source) #####
# Extracting features from query set ...
# Done, obtained 63-by-2048 matrix
# Extracting features from gallery set ...
# Done, obtained 388-by-2048 matrix
# Speed: 0.0155 sec/batch
# Computing distance matrix with metric=euclidean ...
# Computing CMC and mAP ...
# ** Results **
# mAP: 99.2%
# CMC curve
# Rank-1  : 100.0%
# Rank-5  : 100.0%
# Rank-10 : 100.0%
# Rank-20 : 100.0%
# Checkpoint saved to "log/resnet50\model\model.pth.tar-20"
# ##### Evaluating palm_dataset (source) #####
# Extracting features from query set ...
# Done, obtained 63-by-2048 matrix
# Extracting features from gallery set ...
# Done, obtained 388-by-2048 matrix
# Speed: 0.0115 sec/batch
# Computing distance matrix with metric=euclidean ...
# Computing CMC and mAP ...
# ** Results **
# mAP: 100.0%
# CMC curve
# Rank-1  : 100.0%
# Rank-5  : 100.0%
# Rank-10 : 100.0%
# Rank-20 : 100.0%
# Checkpoint saved to "log/resnet50\model\model.pth.tar-30"
# ##### Evaluating palm_dataset (source) #####
# Extracting features from query set ...
# Done, obtained 63-by-2048 matrix
# Extracting features from gallery set ...
# Done, obtained 388-by-2048 matrix
# Speed: 0.0105 sec/batch
# Computing distance matrix with metric=euclidean ...
# Computing CMC and mAP ...
# ** Results **
# mAP: 100.0%
# CMC curve
# Rank-1  : 100.0%
# Rank-5  : 100.0%
# Rank-10 : 100.0%
# Rank-20 : 100.0%
# Checkpoint saved to "log/resnet50\model\model.pth.tar-40"
# ##### Evaluating palm_dataset (source) #####
# Extracting features from query set ...
# Done, obtained 63-by-2048 matrix
# Extracting features from gallery set ...
# Done, obtained 388-by-2048 matrix
# Speed: 0.0124 sec/batch
# Computing distance matrix with metric=euclidean ...
# Computing CMC and mAP ...
# ** Results **
# mAP: 99.9%
# CMC curve
# Rank-1  : 100.0%
# Rank-5  : 100.0%
# Rank-10 : 100.0%
# Rank-20 : 100.0%
# Checkpoint saved to "log/resnet50\model\model.pth.tar-50"
# => Final test
# ##### Evaluating palm_dataset (source) #####
# Extracting features from query set ...
# Done, obtained 63-by-2048 matrix
# Extracting features from gallery set ...
# Done, obtained 388-by-2048 matrix
# Speed: 0.0120 sec/batch
# Computing distance matrix with metric=euclidean ...
# Computing CMC and mAP ...
# ** Results **
# mAP: 100.0%
# CMC curve
# Rank-1  : 100.0%
# Rank-5  : 100.0%
# Rank-10 : 100.0%
# Rank-20 : 100.0%
# Checkpoint saved to "log/resnet50\model\model.pth.tar-60"
# Elapsed 1:14:40
